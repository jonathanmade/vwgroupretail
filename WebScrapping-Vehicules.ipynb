# %%
# !pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (4.12.3)
# Requirement already satisfied: pandas in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\jona_\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import time
import re

base_url = "https://exclusive.vwgroupretail.es/coches/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

data = []

# Primero, averiguamos el número total de páginas
response = requests.get(base_url, headers=headers)
soup = BeautifulSoup(response.text, 'html.parser')

page_total_tag = soup.find('span', class_='r-paginator__mobile-total')
if page_total_tag:
    total_pages = int(page_total_tag.get_text(strip=True))
else:
    # Si no encontramos el total de páginas, por simplicidad se asume 121 como en el ejemplo.
    total_pages = 121

for page in range(1, total_pages+1):
    url = f"{base_url}?page={page}"
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extraer datos del JSON-LD
        # Buscamos la etiqueta con el JSON-LD
        script_tag = soup.find('script', class_='yoast-schema-graph', type='application/ld+json')
        vehicle_dict = {}
        if script_tag:
            data_json = script_tag.get_text(strip=True)
            json_data = json.loads(data_json)

            # Navegamos hasta ItemList y luego los vehículos
            for item in json_data.get('@graph', []):
                if item.get('@type') == 'ItemList':
                    for vehicle_data in item.get('itemListElement', []):
                        vehicle = vehicle_data.get('item', {})
                        if vehicle.get('@type') == 'Vehicle':
                            # productId es un campo único que usaremos para unir con el HTML
                            product_id = vehicle.get('productId', 'N/A')
                            # Extraemos los datos del JSON
                            numberOfDoors = vehicle.get('numberOfDoors', 'N/A')
                            vehicleSeatingCapacity = vehicle.get('vehicleSeatingCapacity', 'N/A')
                            vehicleTransmission = vehicle.get('vehicleTransmission', 'N/A')
                            vehicleModelDate = vehicle.get('vehicleModelDate', 'N/A')
                            fuelType = vehicle.get('fuelType', 'N/A')
                            model = vehicle.get('model', 'N/A')
                            emissionsCO2 = vehicle.get('emissionsCO2', 'N/A')

                            offers = vehicle.get('offers', {})
                            priceCurrency = offers.get('priceCurrency', 'N/A')
                            price_ld = offers.get('price', 'N/A')
                            availability = offers.get('availability', 'N/A')
                            seller = offers.get('seller', {})
                            seller_name = seller.get('name', 'N/A')
                            seller_url = seller.get('url', 'N/A')

                            vehicle_dict[product_id] = {
                                'numberOfDoors': numberOfDoors,
                                'vehicleSeatingCapacity': vehicleSeatingCapacity,
                                'vehicleTransmission': vehicleTransmission,
                                'vehicleModelDate': vehicleModelDate,
                                'fuelType_json': fuelType,  # del JSON
                                'model': model,
                                'emissionsCO2': emissionsCO2,
                                'priceCurrency': priceCurrency,
                                'price_ld': price_ld,
                                'availability': availability,
                                'seller_name': seller_name,
                                'seller_url': seller_url
                            }

        # Extraemos los vehículos del HTML
        vehicles = soup.select('div.card.vcard')  
        if not vehicles:
            print(f"No se encontraron vehículos en la página {page}")
        
        for vehicle in vehicles:
            # Datos desde HTML
            title_tag = vehicle.find('a', class_='vcard--link')
            title = title_tag.get_text(strip=True) if title_tag else 'N/A'
            link = title_tag['href'] if title_tag else 'N/A'

            price_tag = vehicle.find('div', class_='vcard-price__price')
            price_html = price_tag.get_text(strip=True) if price_tag else 'N/A'
            
            info_tag = vehicle.find('p', class_='vcard-consumption__title')
            if info_tag:
                info_text = info_tag.get_text(strip=True)
                parts = info_text.split(' - ')
                if len(parts) == 3:
                    date, kms, fuel = parts
                else:
                    date, kms, fuel = 'N/A', 'N/A', 'N/A'
            else:
                date, kms, fuel = 'N/A', 'N/A', 'N/A'

            # Extraemos productId desde el link (la URL suele terminar con el productId/)
            # Por ejemplo: https://exclusive.vwgroupretail.es/coches/segunda-mano/.../960877/
            product_id_match = re.search(r'/(\d+)/?$', link)
            if product_id_match:
                product_id = product_id_match.group(1)
            else:
                product_id = 'N/A'

            # Datos del JSON para este vehículo
            json_info = vehicle_dict.get(product_id, {})
            
            data.append({
                'productId': product_id,
                'Title': title,
                'Link': link,
                'Date': date,
                'Kms': kms,
                'Fuel_HTML': fuel,  # desde el HTML
                'Price_HTML': price_html,

                # Datos del JSON
                'numberOfDoors': json_info.get('numberOfDoors', 'N/A'),
                'vehicleSeatingCapacity': json_info.get('vehicleSeatingCapacity', 'N/A'),
                'vehicleTransmission': json_info.get('vehicleTransmission', 'N/A'),
                'vehicleModelDate': json_info.get('vehicleModelDate', 'N/A'),
                'fuelType_JSON': json_info.get('fuelType_json', 'N/A'),
                'model': json_info.get('model', 'N/A'),
                'emissionsCO2': json_info.get('emissionsCO2', 'N/A'),
                'priceCurrency': json_info.get('priceCurrency', 'N/A'),
                'price_LD': json_info.get('price_ld', 'N/A'),
                'availability': json_info.get('availability', 'N/A'),
                'seller_name': json_info.get('seller_name', 'N/A'),
                'seller_url': json_info.get('seller_url', 'N/A')
            })

        print(f"Página {page} procesada correctamente")
        time.sleep(2)  # Evita solicitudes muy rápidas

    except Exception as e:
        print(f"Error en la página {page}: {e}")
        time.sleep(5)

df = pd.DataFrame(data)
df.to_csv('vehicles.csv', index=False)
print("Datos guardados en 'vehicles.csv'")
# Out:
# Página 1 procesada correctamente
# Página 2 procesada correctamente
# Página 3 procesada correctamente
# Página 4 procesada correctamente
# Página 5 procesada correctamente
# Página 6 procesada correctamente
# Página 7 procesada correctamente
# Página 8 procesada correctamente
# Página 9 procesada correctamente
# Página 10 procesada correctamente
# Página 11 procesada correctamente
# Página 12 procesada correctamente
# Página 13 procesada correctamente
# Página 14 procesada correctamente
# Página 15 procesada correctamente
# Página 16 procesada correctamente
# Página 17 procesada correctamente
# Página 18 procesada correctamente
# Página 19 procesada correctamente
# Página 20 procesada correctamente
# Página 21 procesada correctamente
# Página 22 procesada correctamente
# Página 23 procesada correctamente
# Página 24 procesada correctamente
# Página 25 procesada correctamente
# Página 26 procesada correctamente
# Página 27 procesada correctamente
# Página 28 procesada correctamente
# Página 29 procesada correctamente
# Página 30 procesada correctamente
# Página 31 procesada correctamente
# Página 32 procesada correctamente
# Página 33 procesada correctamente
# Página 34 procesada correctamente
# Página 35 procesada correctamente
# Página 36 procesada correctamente
# Página 37 procesada correctamente
# Página 38 procesada correctamente
# Página 39 procesada correctamente
# Página 40 procesada correctamente
# Página 41 procesada correctamente
# Página 42 procesada correctamente
# Página 43 procesada correctamente
# Página 44 procesada correctamente
# Página 45 procesada correctamente
# Página 46 procesada correctamente
# Página 47 procesada correctamente
# Página 48 procesada correctamente
# Página 49 procesada correctamente
# Página 50 procesada correctamente
# Página 51 procesada correctamente
# Página 52 procesada correctamente
# Página 53 procesada correctamente
# Página 54 procesada correctamente
# Página 55 procesada correctamente
# Página 56 procesada correctamente
# Página 57 procesada correctamente
# Página 58 procesada correctamente
# Página 59 procesada correctamente
# Página 60 procesada correctamente
# Página 61 procesada correctamente
# Página 62 procesada correctamente
# Página 63 procesada correctamente
# Página 64 procesada correctamente
# Página 65 procesada correctamente
# Página 66 procesada correctamente
# Página 67 procesada correctamente
# Página 68 procesada correctamente
# Página 69 procesada correctamente
# Página 70 procesada correctamente
# Página 71 procesada correctamente
# Página 72 procesada correctamente
# Página 73 procesada correctamente
# Página 74 procesada correctamente
# Página 75 procesada correctamente
# Página 76 procesada correctamente
# Página 77 procesada correctamente
# Página 78 procesada correctamente
# Página 79 procesada correctamente
# Página 80 procesada correctamente
# Página 81 procesada correctamente
# Página 82 procesada correctamente
# Página 83 procesada correctamente
# Página 84 procesada correctamente
# Página 85 procesada correctamente
# Página 86 procesada correctamente
# Página 87 procesada correctamente
# Página 88 procesada correctamente
# Página 89 procesada correctamente
# Página 90 procesada correctamente
# Página 91 procesada correctamente
# Página 92 procesada correctamente
# Página 93 procesada correctamente
# Página 94 procesada correctamente
# Página 95 procesada correctamente
# Página 96 procesada correctamente
# Página 97 procesada correctamente
# Página 98 procesada correctamente
# Página 99 procesada correctamente
# Página 100 procesada correctamente
# Página 101 procesada correctamente
# Página 102 procesada correctamente
# Página 103 procesada correctamente
# Página 104 procesada correctamente
# Página 105 procesada correctamente
# Página 106 procesada correctamente
# Página 107 procesada correctamente
# Página 108 procesada correctamente
# Página 109 procesada correctamente
# Página 110 procesada correctamente
# Página 111 procesada correctamente
# Página 112 procesada correctamente
# Página 113 procesada correctamente
# Página 114 procesada correctamente
# Página 115 procesada correctamente
# Página 116 procesada correctamente
# Página 117 procesada correctamente
# Página 118 procesada correctamente
# Página 119 procesada correctamente
# Página 120 procesada correctamente
# Página 121 procesada correctamente
# Datos guardados en 'vehicles.csv'

# %%
print(soup.prettify())  # Esto imprimirá el contenido HTML de la página
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="https://exclusive.vwgroupretail.es/xmlrpc.php" rel="pingback"/>
#   <script type="text/javascript">
#    window.dataLayer = window.dataLayer || [];
#             function gtag() { dataLayer.push(arguments); }
#   </script>
#   <script type="text/javascript">
#    var iubenda_configuration_options = {"lang":"es","siteId":1783013,"cookiePolicyId":56337298,"consentOnScroll":false,"consentOnLinkAndButton":false,"perPurposeConsent":true,"consentOnElement":"","preferenceCookie":{"expireAfter":365},"banner":{"position":"bottom","content":"Este sitio web y las herramientas de terceros integradas en \u00e9l procesan datos personales (por ejemplo, datos de navegaci\u00f3n o direcciones IP) y utilizan cookies, p\u00edxeles, etiquetas u otros identificadores necesarios para el funcionamiento y para lograr los fines descritos en la pol\u00edtica de cookies. , incluida la funcionalidad mejorada del sitio web y la publicidad personalizada. Al hacer clic en el bot\u00f3n Aceptar todo, declara que acepta el uso de estas tecnolog\u00edas. Alternativamente, puede personalizar sus elecciones usando el bot\u00f3n adSaber m\u00e1s y personalizarecuado.  \/ Aceptar","acceptButtonCaption":"Aceptar","rejectButtonCaption":"Rechazar","customizeButtonCaption":"Saber m\u00e1s y personalizar","backgroundOverlay":false,"backgroundColor":"#000","textColor":"#fff","fontSize":0,"acceptButtonDisplay":true,"acceptButtonColor":"#0073ce","acceptButtonCaptionColor":"#fff","rejectButtonColor":"#0073ce","rejectButtonCaptionColor":"#fff","customizeButtonColor":"#212121","customizeButtonCaptionColor":"#fff","customizeButtonDisplay":true,"slideDown":true,"innerHtmlCloseBtn":"x","rejectButtonDisplay":false,"closeButtonDisplay":true,"closeButtonRejects":true},"callback":{"onReady":"","onPreferenceFirstExpressed":""}};
#   </script>
#   <script src="https://exclusive.vwgroupretail.es/wp-content/plugins/jcookielaw/dist/jcookielaw-iubenda.js" type="text/javascript">
#   </script>
#   <script async="" charset="UTF-8" src="//cdn.iubenda.com/cs/beta/iubenda_cs.js" type="text/javascript">
#   </script>
#   <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
#    <!-- This site is optimized with the Yoast SEO plugin v23.9 - https://yoast.com/wordpress/plugins/seo/ -->
#    <title>
#     Todos los vehículos a la venta en Volkswagen Group Retail Spain
#    </title>
#    <meta content="Descubre nuestros 1801 Coches a la venta hoy desde 6.990 € en Volkswagen Group Retail Spain" name="description">
#     <link href="https://exclusive.vwgroupretail.es/coches/" rel="canonical">
#      <link href="https://exclusive.vwgroupretail.es/coches/?page=2" rel="next">
#       <meta content="es_ES" property="og:locale">
#        <meta content="website" property="og:type">
#         <meta content="Todos los vehículos a la venta en Volkswagen Group Retail Spain" property="og:title"/>
#         <meta content="VGRS Exclusive" property="og:site_name"/>
#         <meta content="summary_large_image" name="twitter:card"/>
#         <meta content="Todos los vehículos a la venta en Volkswagen Group Retail Spain" name="twitter:title"/>
#         <script class="yoast-schema-graph" type="application/ld+json">
#          {"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://exclusive.vwgroupretail.es/#website","url":"https://exclusive.vwgroupretail.es/","name":"VGRS Exclusive","description":"Coches nuevos y ocasion  Volkswagen, Audi, SEAT, Skoda Y Cupra ","potentialAction":[{"@type":"SearchAction","target":{"@type":"EntryPoint","urlTemplate":"https://exclusive.vwgroupretail.es/?s={search_term_string}"},"query-input":{"@type":"PropertyValueSpecification","valueRequired":true,"valueName":"search_term_string"}}],"inLanguage":"es"},{"@type":"BreadcrumbList","@id":"#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"WebPage","@id":"https://exclusive.vwgroupretail.es","url":"https://exclusive.vwgroupretail.es","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@type":"WebPage","name":"Coches"}}]},{"@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@type":"Vehicle","url":"https://exclusive.vwgroupretail.es/coches/segunda-mano/madrid/volkswagen/transporter/otro/mixto-corto-tn-2-0-tdi-81kw-110cv-bmt/960877/","name":"Volkswagen Transporter Mixto Corto TN 2.0 TDI 81kW (110CV) BMT 2021","color":"","image":"https://cdn.dealerk.es/dealer/datafiles/vehicle/images/$original$/473/nl4ZrS0yIgzmmR4E.jpeg","sku":"960877","productId":"960877","model":"transporter","fuelType":"Otro","numberOfDoors":4,"vehicleSeatingCapacity":5,"vehicleTransmission":"manual","vehicleModelDate":2021,"vehicleInteriorColor":"","emissionsCO2":155,"description":"","mileageFromOdometer":{"@type":"QuantitativeValue","value":117100,"unitCode":"KMT"},"brand":{"@type":"Brand","name":"Volkswagen","url":"https://exclusive.vwgroupretail.es/coches/todos-tipos/todas-ciudades/volkswagen/"},"manufacturer":{"@type":"Corporation","name":"Volkswagen","url":"https://exclusive.vwgroupretail.es/coches/todos-tipos/todas-ciudades/volkswagen/"},"offers":{"@type":"Offer","url":"https://exclusive.vwgroupretail.es/coches/segunda-mano/madrid/volkswagen/transporter/otro/mixto-corto-tn-2-0-tdi-81kw-110cv-bmt/960877/","priceCurrency":"EUR","price":27500,"availability":"https://schema.org/InStock","itemCondition":"https://schema.org/UsedCondition","seller":{"@type":"AutoDealer","name":"Castellana Wagen","url":"https://exclusive.vwgroupretail.es","image":"https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain.png","telephone":"912582741","address":{"@type":"PostalAddress","addressLocality":"Madrid","addressCountry":"ES","streetAddress":"Calle Isla de Java, nº 1"}}}}},{"@type":"ListItem","position":2,"item":{"@type":"Vehicle","url":"https://exclusive.vwgroupretail.es/coches/segunda-mano/madrid/volkswagen/t-cross/gasolina/advance-1-0-tsi-81kw-110cv/960876/","name":"Volkswagen T-Cross Advance 1.0 TSI 81kW (110CV) 2023","color":"","image":"https://cdn.dealerk.es/dealer/datafiles/vehicle/images/$original$/473/WkChEtt93yH7OlXe.jpeg","sku":"960876","productId":"960876","model":"t-cross","fuelType":"Gasolina","numberOfDoors":5,"vehicleSeatingCapacity":5,"vehicleTransmission":"manual","vehicleModelDate":2023,"vehicleInteriorColor":"","emissionsCO2":131,"description":"","mileageFromOdometer":{"@type":"QuantitativeValue","value":36054,"unitCode":"KMT"},"brand":{"@type":"Brand","name":"Volkswagen","url":"https://exclusive.vwgroupretail.es/coches/todos-tipos/todas-ciudades/volkswagen/"},"manufacturer":{"@type":"Corporation","name":"Volkswagen","url":"https://exclusive.vwgroupretail.es/coches/todos-tipos/todas-ciudades/volkswagen/"},"offers":{"@type":"Offer","url":"https://exclusive.vwgroupretail.es/coches/segunda-mano/madrid/volkswagen/t-cross/gasolina/advance-1-0-tsi-81kw-110cv/960876/","priceCurrency":"EUR","price":20900,"availability":"https://schema.org/InStock","itemCondition":"https://schema.org/UsedCondition","seller":{"@type":"AutoDealer","name":"Castellana Wagen","url":"https://exclusive.vwgroupretail.es","image":"https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_r ...
#         </script>
#         <!-- / Yoast SEO plugin. -->
#         <link href="//webspark-assets.dealerk.com" rel="dns-prefetch"/>
#         <link href="//cdnwp.dealerk.com" rel="dns-prefetch"/>
#         <style id="classic-theme-styles-inline-css">
#          /*! This file is auto-generated */ .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
#         </style>
#         <link crossorigin="anonymous" href="https://webspark-assets.dealerk.com/webspark-revolution/2.0.9/dist/Kernel/webspark.css?ver=6.6.2" id="ws-core-css" integrity="sha256-ve9NtocchEzjfbYzNKs/UHr5lbq++2FHbycsmh+1SaM=" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://webspark-assets.dealerk.com/webspark-revolution/2.0.9/dist/EnergyLabel/EnergyLabel/footer-disclaimer.css?ver=6.6.2" id="ws-energylabel-energylabel-footer-disclaimer-css" integrity="sha256-Qb2MYziWiazvRFZFmFY8773oUhJWsAmThVZ9zlAmwA4=" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://webspark-assets.dealerk.com/webspark-revolution/2.0.9/dist/LiveSpark/widget.css?ver=6.6.2" id="ws-livespark-widget-css" integrity="sha256-3uv3WoV1yeR2xOtSy5GPMWzdUDN3aXpChmhBK2KoFSw=" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://webspark-assets.dealerk.com/webspark-revolution/2.0.9/dist/Shared/vehicle-card/classic.css?ver=6.6.2" id="ws-shared-vehicle-card-classic-css" integrity="sha256-9CcueeRdSjk4Z878UgGsQgcg/Dne6AG9NWCftL/L0pc=" media="all" rel="stylesheet"/>
#         <link crossorigin="anonymous" href="https://webspark-assets.dealerk.com/webspark-revolution/2.0.9/dist/EnergyLabel/EmissionsConsumptionsBlock/emissions-consumptions.css?ver=6.6.2" id="ws-energylabel-emissionsconsumptionsblock-emissions-consumptions-css" integrity="sha256-N+M//6PIEXlmLhnDcZL+tqVLNW5P4TJj9BkROrlrY90=" media="all" rel="stylesheet"/>
#         <link href="https://webspark-assets.dealerk.com/webspark/1.313.5/css/style-vendors-revo.css?ver=1.313.5" id="webspark-vendors-css" media="all" rel="stylesheet"/>
#         <link href="https://webspark-assets.dealerk.com/webspark/1.313.5/css/style-elektron-revo.css?ver=1.313.5" id="style-elektron-css" media="all" rel="stylesheet"/>
#         <link href="https://exclusive.vwgroupretail.es/wp-content/plugins/webspark/js/vendor/pickerjs/themes/default.css?ver=6.6.2" id="pickerjs-default-css" media="all" rel="stylesheet"/>
#         <link href="https://exclusive.vwgroupretail.es/wp-content/plugins/webspark/js/vendor/pickerjs/themes/default.date.css?ver=6.6.2" id="pickerjs-default-date-css" media="all" rel="stylesheet"/>
#         <link href="https://exclusive.vwgroupretail.es/wp-content/plugins/webspark/js/vendor/pickerjs/themes/default.time.css?ver=6.6.2" id="pickerjs-default-time-css" media="all" rel="stylesheet"/>
#         <link href="https://webspark-assets.dealerk.com/webspark-theme/1.313.5/style.css?ver=1.313.5" id="webspark-theme-css" media="all" rel="stylesheet"/>
#         <link href="https://exclusive.vwgroupretail.es/wp-content/themes/websparksites-es-theme/volkswagen-retail/style.css?ver=1728930326" id="webspark-boilerplate-theme-css" media="all" rel="stylesheet"/>
#         <style id="webspark-boilerplate-theme-inline-css">
#          :root {--color__primary-light:15,165,233;--color__primary:0,152,221;--color__primary-dark:10,129,183;--color__secondary-light:81,91,99;--color__secondary:55,63,69;--color__secondary-dark:32,38,41;--color__tertiary-light:153,153,153;--color__tertiary:102,102,102;--color__tertiary-dark:51,51,51;--color__white:255,255,255;--color__gray-lighter:242,242,242;--color__gray-light:199,199,199;--color__gray:148,148,148;--color__gray-dark:97,97,97;--color__gray-darker:46,46,46;--color__black:0,0,0;--color__body-bg:253,253,254;--color__wishlist:217,30,24;--color__error:194,42,27;--color__error-dark:170,0,40;--color__error-light:245,225,228;--color__warning:236,182,12;--color__warning-dark:199,153,10;--color__warning-light:255,204,45;--color__error-light-new:205,80,68;--color__yellow-paypal:255,196,57;--color__yellow-paypal-light:255,192,44;--color__reserved:184,22,42;--color__reserved-dark:165,19,37;--color__gold:247,181,24;--color__offer:238,51,51;--color__online:47,93,152;--color__success:58,186,121;--color__success-light:81,200,139;--color__success-dark:36,154,94;--color__info:92,180,228;--color__category-demo:51,124,151;--color__labela:92,180,228;--color__labelb:12,94,149;--color__labelc:59,182,119;--color__labeld:234,38,98;--color__labele:45,220,108;--color__labelf:83,127,160;--color__labelg:238,51,51;--color__labelh:123,119,201;--color__labeli:186,129,0;--color__labell:45,75,220;--color__labelm:237,198,90;--color__twitter:0,172,237;--color__twitter-hover:0,132,180;--color__facebook:59,89,151;--color__facebook-hover:45,67,114;--color__google:62,130,247;--color__google-hover:49,104,197;--color__googleplus:214,73,55;--color__googleplus-hover:181,53,37;--color__pinterest:189,8,28;--color__pinterest-hover:189,8,28;--color__linkedin:0,116,161;--color__linkedin-hover:0,98,136;--color__whatsapp:67,216,84;--color__whatsapp-hover:0,150,136;--font__primary:'Source Sans Pro';--font__secondary:'Source Sans Pro';--color__grey-lighter:243,245,246;}}
#         </style>
#         <link href="https://webspark-assets.dealerk.com/fonts/source-sans-pro-regular-source-sans-pro-bold.css" id="webspark-font-css" media="all" rel="stylesheet"/>
#         <link href="https://exclusive.vwgroupretail.es/wp-json/" rel="https://api.w.org/"/>
#         <link href="https://exclusive.vwgroupretail.es/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#         <script type="text/javascript">
#          var WSKModules = ["analytics","brand_universe","downpayment","elementor","live_spark","custom_ctas","oem_offers","renting_offers","stock","tradein","vehicle_comparison"];
# var WSKRoute = "stock.car.listing";
# var WSKi18n = {"locale":"es-ES","iconSet":"https:\/\/exclusive.vwgroupretail.es\/wp-content\/mu-plugins\/webspark-revolution\/dist\/svg\/volkswagen.defs.svg#","lang":"es","currencySymbol":"\u20ac","thousands":".","decimals":",","currencyRightSide":true,"distanceSymbol":"Km","weightSymbol":"Kg","dateTime":{"dateFormat":"d MM, yyyy","days":["domingo","lunes","martes","mi\u00e9rcoles","jueves","viernes","s\u00e1bado"],"months":["Enero","Febrero","Marzo","Abril","Mayo","Junio","Julio","Agosto","Septiembre","Octubre","Noviembre","Diciembre"],"today":"Hoy","monthsTitle":"Meses","clear":"Reestablecer","weekstart":"1"},"dictionary":{"months":"Meses"}};
#         </script>
#         <!-- Stream WordPress user activity plugin v4.0.2 -->
#         <!-- Google Tag Manager -->
#         <!-- generated with webspark-tc-automation plugin-->
#         <script class="_iub_cs_activate-inline" type="text/plain">
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 					new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 					j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 					'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 					})(window,document,'script','dataLayer','GTM-5WDTR9T');
#         </script>
#         <!-- End Google Tag Manager -->
#         <!-- Google Tag Manager -->
#         <!-- generated with webspark-tc-automation plugin-->
#         <script class="_iub_cs_activate-inline" type="text/plain">
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 					new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 					j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 					'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 					})(window,document,'script','dataLayer','GTM-WD6BQ3W');
#         </script>
#         <!-- End Google Tag Manager -->
#         <!-- Google Tag Manager -->
#         <!-- generated with webspark-tc-automation plugin-->
#         <script class="_iub_cs_activate-inline" type="text/plain">
#          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 					new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 					j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 					'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 					})(window,document,'script','dataLayer','GTM-KHB2ZNX');
#         </script>
#         <!-- End Google Tag Manager -->
#         <script>
#          var WSModules = '["AcfFields","Amp","Analytics","BrandsHP","DealerCpts","DownPaymentButton","EnergyLabel","Favourites","ListingPages","Loan","MarketingSuite","Matomo","Offers","RobotsEditor","SocialLogin","Sso","StockOffers","UsedEstimation"]';
#         </script>
#         <meta content="Vqs3EImQvVGI4Q5pa7j51N9PrTCDjfYKNjzAKAL-fVc" name="google-site-verification"/>
#         <meta content="4BKw88bnpuReYNnnEShY7Jth2oeA1O2L0H0Nv2MUiGQ" name="google-site-verification"/>
#         <meta content="2v6lqnedszqxoeaf2on5na8qq0spn0" name="facebook-domain-verification"/>
#         <meta content="nUjVM7q_eRMz-R2RdXjxVy5uVwIa1ctTk0UpaOmk5NA" name="google-site-verification"/>
#         <meta content="Elementor 3.16.6; features: e_dom_optimization, e_optimized_assets_loading, additional_custom_breakpoints; settings: css_print_method-external, google_font-enabled, font_display-swap" name="generator"/>
#         <meta content="seminuevos, seminuevos multimarca" name="keywords"/>
#         <link href="https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2023/05/cropped-1052x400_adaptacion1-1-32x32.jpg" rel="icon" sizes="32x32"/>
#         <link href="https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2023/05/cropped-1052x400_adaptacion1-1-192x192.jpg" rel="icon" sizes="192x192"/>
#         <link href="https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2023/05/cropped-1052x400_adaptacion1-1-180x180.jpg" rel="apple-touch-icon"/>
#         <meta content="https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2023/05/cropped-1052x400_adaptacion1-1-270x270.jpg" name="msapplication-TileImage">
#          <!-- Google Tag Manager -->
#          <script class="_iub_cs_activate _iub_cs_activate-inline" data-iub-purposes="1" type="text/plain">
#           (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MTGFDZJ');
#          </script>
#          <!-- End Google Tag Manager -->
#          <!-- Start Insights Pixel -->
#          <script>
#           var tD=(new Date).toISOString().slice(0,10);window.sfpid = 348035;var u="https://serviceform.com/analytics/sf-pixel.js?"+tD,t=document.createElement("script");t.setAttribute("type","text/javascript"),t.setAttribute("src",u),t.async=!0,(document.getElementsByTagName("head")[0]||document.documentElement).appendChild(t);
#          </script>
#          <!-- End Serviceform Insights Pixel -->
#          <style id="wp-custom-css">
#           /* Ocultar precio nuevo del coche tachado */ .c-price__discount, .c-price__initial-price, .page-id-76 .badge--offer-rect {display:none!important;} .price__val.price__val--full.u-margin-right--xs{display:none!important;}  /* Cambiar color de fondo form valoracion de coche */ .step--passed { 	background-color: white }
#          </style>
#          <script>
#           var dataLayer = window.dataLayer || []; dataLayer.push({"submodelList":["960877","960876","960875","960874","960873","960872","960871","960870","960869","960653","960650","960649","960648","960647","960645"]});
#          </script>
#         </meta>
#        </meta>
#       </meta>
#      </link>
#     </link>
#    </meta>
#   </meta>
#  </head>
#  <body class="coches wsr is-header-stickyClassic preload icon-set__volkswagen is-sales-website icon-set-volkswagen dk-desktop dk-elektron has-sticky-contacts-v1 atomik-theme elementor-default elementor-kit-5026 has-vehicle-comparison" data-area="default" data-header-type="stickyClassic">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe class="_iub_cs_activate" data-iub-purposes="2" height="0" src="//cdn.iubenda.com/cookie_solution/empty.html" style="display:none;visibility:hidden" suppressedsrc="https://www.googletagmanager.com/ns.html?id=GTM-MTGFDZJ" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!-- Google Tag Manager (noscript) -->
#   <!-- generated with webspark-tc-automation plugin-->
#   <noscript>
#    <iframe class="_iub_cs_activate" data-iub-purposes="2" height="0" src="//cdn.iubenda.com/cookie_solution/empty.html" style="display:none;visibility:hidden" suppressedsrc="https://www.googletagmanager.com/ns.html?id=GTM-5WDTR9T" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!-- Google Tag Manager (noscript) -->
#   <!-- generated with webspark-tc-automation plugin-->
#   <noscript>
#    <iframe class="_iub_cs_activate" data-iub-purposes="2" height="0" src="//cdn.iubenda.com/cookie_solution/empty.html" style="display:none;visibility:hidden" suppressedsrc="https://www.googletagmanager.com/ns.html?id=GTM-WD6BQ3W" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!-- Google Tag Manager (noscript) -->
#   <!-- generated with webspark-tc-automation plugin-->
#   <noscript>
#    <iframe class="_iub_cs_activate" data-iub-purposes="2" height="0" src="//cdn.iubenda.com/cookie_solution/empty.html" style="display:none;visibility:hidden" suppressedsrc="https://www.googletagmanager.com/ns.html?id=GTM-KHB2ZNX" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <section id="js-loader-wrap">
#   </section>
#   <section class="site-wrap" id="wrap">
#    <button class="icon icon--menu icon--menu__close is-hidden main-banner__btn--close main-banner__btn js-toggle-nav">
#     <span class="icon--menu__icon-content">
#      <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#       <polygon fill="#000000" fill-rule="evenodd" points="11.778 10.364 18.142 4 19.556 5.414 13.192 11.778 19.556 18.142 18.142 19.556 11.778 13.192 5.414 19.556 4 18.142 10.364 11.778 4 5.414 5.414 4">
#       </polygon>
#      </svg>
#     </span>
#    </button>
#    <section class="main-banner main-banner--fixed u-hidden-from--large-m" id="main-banner">
#     <section id="js-personal-area-menu-mount--mobile">
#     </section>
#     <section class="main-banner--narrow flexgrid flexgrid--full flexgrid--middle flexgrid--center">
#      <button class="icon icon--menu main-banner__btn icon--menu__open js-toggle-nav">
#       <span class="icon--menu__icon-content">
#        <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#         <path d="M2 18.652v-1.667h16.667v1.667H2zm0-5.834v-1.666h11.667v1.666H2zm0-5.833V5.318h20v1.667H2z" fill-rule="evenodd">
#         </path>
#        </svg>
#       </span>
#      </button>
#      <section class="logo-menu main-banner__logo-menu u-text--center">
#       <div class="logo-menu__heading">
#        <a class="logo-menu__link" href="https://exclusive.vwgroupretail.es" title="Volver a la Home">
#         <img alt="VGRS Exclusive " class="attachment-logo-desktop size-logo-desktop" height="72" src="https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-184x72.png" srcset="https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-184x72.png 184w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-300x117.png 300w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-1024x400.png 1024w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-768x300.png 768w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-1536x600.png 1536w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-128x50.png 128w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-164x64.png 164w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-123x48.png 123w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-360x141.png 360w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain.png 1842w" width="184"/>
#        </a>
#       </div>
#      </section>
#     </section>
#    </section>
#    <header class="main-header main-header--v1" id="main-header">
#     <div class="main-header__top">
#      <div class="grid-wrapper">
#       <div class="grid">
#        <div class="grid__item">
#         <div class="main-header__flex-wrapper">
#          <div class="main-header__flex-item">
#           <div class="service-menu__container">
#            <ul class="service-menu service-menu--info service-menu--grid">
#            </ul>
#           </div>
#           <!-- closes service-menu__container -->
#          </div>
#          <div class="main-header__flex-item">
#           <div class="main-header__flex-wrapper">
#            <div data-class="u-hidden-till--large-m u-margin-right--s" id="js-personal-area-menu-mount">
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="main-header__body">
#      <div class="grid-wrapper">
#       <div class="grid">
#        <div class="grid__item">
#         <div class="flexgrid flexgrid--middle flexgrid--full flexgrid--center">
#          <section class="main-header__logo-section logo-menu u-padding-right--s">
#           <div class="logo-menu__heading">
#            <a class="logo-menu__link" href="https://exclusive.vwgroupretail.es" title="Volver a la Home">
#             <img alt="VGRS Exclusive " class="attachment-logo-desktop size-logo-desktop" height="72" src="https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-184x72.png" srcset="https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-184x72.png 184w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-300x117.png 300w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-1024x400.png 1024w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-768x300.png 768w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-1536x600.png 1536w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-128x50.png 128w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-164x64.png 164w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-123x48.png 123w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain-360x141.png 360w, https://cdnwp.dealerk.com/8c54192f/uploads/sites/49/2020/10/volkswagen_group_retail_spain.png 1842w" width="184"/>
#            </a>
#           </div>
#          </section>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="main-header__menu-wrapper">
#      <div class="grid-wrapper">
#       <div class="grid">
#        <div class="grid__item">
#         <nav class="menu menu--main" id="navigation">
#          <ul class="menu__list menu__list--level-1 menu__list--base flexgrid--center" id="menu-main">
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu__item menu__item--level-1 js-toggle-submenu menu-item-245" id="menu-item-245">
#            <a class="menu__link" href="#">
#             <span class="menu__text">
#              Vehículos Nuevos
#             </span>
#             <span class="menu__icon">
#              <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M2.875 7l8.623 9.012c.255.273.38.362.502.362.132 0 .282-.104.521-.357L21.124 7l.876.836-8.599 9.013a1.92 1.92 0 01-1.401.738 1.898 1.898 0 01-1.382-.741L2 7.837 2.875 7z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </a>
#            <nav class="menu menu--sub menu--overlap">
#             <ul class="menu__list menu__list--sub">
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-247" id="menu-item-247">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/coches/nuevos/volkswagen/">
#                <span class="menu__text">
#                 Volkswagen
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-248" id="menu-item-248">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/coches/nuevos/audi/">
#                <span class="menu__text">
#                 Audi
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-249" id="menu-item-249">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/coches/nuevos/seat/">
#                <span class="menu__text">
#                 SEAT
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-1658" id="menu-item-1658">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/coches/nuevos/cupra/">
#                <span class="menu__text">
#                 Cupra
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-1657" id="menu-item-1657">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/coches/nuevos/skoda/">
#                <span class="menu__text">
#                 Skoda
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-5077" id="menu-item-5077">
#               <a class="menu__link" href="/coches/nuevos/porsche/">
#                <span class="menu__text">
#                 Porsche
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-1910" id="menu-item-1910">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/vehiculos-comerciales/volkswagen/">
#                <span class="menu__text">
#                 Vehículos Comerciales
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-365" id="menu-item-365">
#               <a class="menu__link" href="/vehiculos-nuevos-stock/">
#                <span class="menu__text">
#                 Vehículos en stock
#                </span>
#               </a>
#              </li>
#             </ul>
#            </nav>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--level-1 menu-item-250" id="menu-item-250">
#            <a class="menu__link" href="https://exclusive.vwgroupretail.es/vehiculo-de-ocasion/">
#             <span class="menu__text">
#              Vehículos Ocasión
#             </span>
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--level-1 menu-item-2060" id="menu-item-2060">
#            <a class="menu__link" href="https://exclusive.vwgroupretail.es/servicio-oficial-posventa/">
#             <span class="menu__text">
#              Posventa
#             </span>
#            </a>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu__item menu__item--level-1 js-toggle-submenu menu-item-246" id="menu-item-246">
#            <a class="menu__link" href="#">
#             <span class="menu__text">
#              Ofertas
#             </span>
#             <span class="menu__icon">
#              <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M2.875 7l8.623 9.012c.255.273.38.362.502.362.132 0 .282-.104.521-.357L21.124 7l.876.836-8.599 9.013a1.92 1.92 0 01-1.401.738 1.898 1.898 0 01-1.382-.741L2 7.837 2.875 7z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </a>
#            <nav class="menu menu--sub menu--overlap">
#             <ul class="menu__list menu__list--sub">
#              <li class="menu-item menu-item-type-taxonomy menu-item-object-brand_tax menu__item menu__item--sub menu-item-240" id="menu-item-240">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/marca-categoria/vehiculo-nuevo/">
#                <span class="menu__text">
#                 Ofertas vehículo nuevo
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-taxonomy menu-item-object-brand_tax menu__item menu__item--sub menu-item-279" id="menu-item-279">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/marca-categoria/vehiculo-ocasion/">
#                <span class="menu__text">
#                 Ofertas vehículo ocasión
#                </span>
#               </a>
#              </li>
#             </ul>
#            </nav>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu__item menu__item--level-1 js-toggle-submenu menu-item-586" id="menu-item-586">
#            <a class="menu__link" href="https://exclusive.vwgroupretail.es/noticias/">
#             <span class="menu__text">
#              Noticias
#             </span>
#             <span class="menu__icon">
#              <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M2.875 7l8.623 9.012c.255.273.38.362.502.362.132 0 .282-.104.521-.357L21.124 7l.876.836-8.599 9.013a1.92 1.92 0 01-1.401.738 1.898 1.898 0 01-1.382-.741L2 7.837 2.875 7z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </a>
#            <nav class="menu menu--sub menu--overlap">
#             <ul class="menu__list menu__list--sub">
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-743" id="menu-item-743">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/category/ecomobility/" title="Blog Eco Mobility">
#                <span class="menu__text">
#                 EcoMobility
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page u-hidden-from--large-m menu__item--view-all menu__item menu__item--sub menu-item-586">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/noticias/">
#                <span class="menu__text">
#                 Todo de Noticias
#                </span>
#               </a>
#              </li>
#             </ul>
#            </nav>
#           </li>
#           <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-has-children menu__item menu__item--level-1 js-toggle-submenu menu-item-4982" id="menu-item-4982">
#            <a class="menu__link" href="#">
#             <span class="menu__text">
#              Servicios
#             </span>
#             <span class="menu__icon">
#              <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M2.875 7l8.623 9.012c.255.273.38.362.502.362.132 0 .282-.104.521-.357L21.124 7l.876.836-8.599 9.013a1.92 1.92 0 01-1.401.738 1.898 1.898 0 01-1.382-.741L2 7.837 2.875 7z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </a>
#            <nav class="menu menu--sub menu--overlap">
#             <ul class="menu__list menu__list--sub">
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-1598" id="menu-item-1598">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/empresas/">
#                <span class="menu__text">
#                 Empresas
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu__item menu__item--sub menu-item-903" id="menu-item-903">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/financiacion/">
#                <span class="menu__text">
#                 Financiación
#                </span>
#               </a>
#              </li>
#             </ul>
#            </nav>
#           </li>
#           <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-has-children menu__item menu__item--level-1 js-toggle-submenu menu-item-128" id="menu-item-128">
#            <a class="menu__link" href="https://exclusive.vwgroupretail.es/quienes-somos/">
#             <span class="menu__text">
#              Nosotros
#             </span>
#             <span class="menu__icon">
#              <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#               <path d="M2.875 7l8.623 9.012c.255.273.38.362.502.362.132 0 .282-.104.521-.357L21.124 7l.876.836-8.599 9.013a1.92 1.92 0 01-1.401.738 1.898 1.898 0 01-1.382-.741L2 7.837 2.875 7z" fill-rule="evenodd">
#               </path>
#              </svg>
#             </span>
#            </a>
#            <nav class="menu menu--sub menu--overlap">
#             <ul class="menu__list menu__list--sub">
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu__item menu__item--sub menu-item-2603" id="menu-item-2603">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/trabaja-con-nosotros/">
#                <span class="menu__text">
#                 Trabaja con nosotros
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-custom menu-item-object-custom menu__item menu__item--sub menu-item-166" id="menu-item-166">
#               <a class="menu__link" href="/concesionarios/">
#                <span class="menu__text">
#                 Concesionarios
#                </span>
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page u-hidden-from--large-m menu__item--view-all menu__item menu__item--sub menu-item-128">
#               <a class="menu__link" href="https://exclusive.vwgroupretail.es/quienes-somos/">
#                <span class="menu__text">
#                 Todo de Nosotros
#                </span>
#               </a>
#              </li>
#             </ul>
#            </nav>
#           </li>
#          </ul>
#         </nav>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="js-notification-manager">
#    </div>
#    <section class="page-wrap" id="page-wrap">
#     <div class="page-container page-layout-default layout-default--wrapper stock-listing--wrapper" id="main">
#      <div class="layout-default--area layout-default-area--top stock-listing-area--top">
#       <article class="ws-widget ws-widget-wrapper stock-listing-title-widget ws-widget-area-stock_listing_content" id="stock-listing-title-widget-3">
#        <section class="section section__unboxed section__full-width--none section__spacing--none stock-listing-title">
#         <div class="section__content">
#          <h1 class="text text__display-large text__color--inherit text__font--primary stock-listing-title__value">
#           <strong>
#            <span x-data="WSK.ListingTitle('Todos los vehículos ')" x-text="title">
#             Todos los vehículos
#            </span>
#           </strong>
#          </h1>
#         </div>
#        </section>
#       </article>
#       <article class="ws-widget ws-widget-wrapper stock-listing-widget ws-widget-area-stock_listing_content" id="stock-listing-widget-5">
#        <main class="stock-listing" x-data="WSK.StockListing('stockListing-675c0c904783a')" x-init="initListing()">
#         <script id="sl-data" type="application/json">
#          {"showSortBy":true,"nonce":"3b3ef4e0f2","filtersLayout":"sidebar","sortByDefaultValue":"enteredInStockDate|desc","mobileAsyncApply":true}
#         </script>
#         <div class="stock-listing__actions r-filters wsk-sticky-element--top" x-data="WSK.Sticky($el, '.stock-listing__results-feedback')">
#          <div class="stock-listing__actions-buttons">
#           <button @click="toggleMobileSortBy" class="r-button button button--kind-secondary button--size-md button--theme-secondary button--radius-default stock-listing__actions-buttons--full">
#            <div class="button__content">
#             Ordenar por
#             <svg class="revo icon icon--svg icon-- icon--xs icon--currentColor">
#              <use xlink:href="https://exclusive.vwgroupretail.es/wp-content/mu-plugins/webspark-revolution/dist/svg/volkswagen.defs.svg#sort">
#              </use>
#             </svg>
#            </div>
#           </button>
#           <button @click="toggleMobileFilters" class="r-button button button--kind-secondary button--size-md button--theme-secondary button--radius-default stock-listing__actions-buttons--full">
#            <div class="button__content">
#             Filtros
#             <span x-text="getAppliedFiltersCounterLabel()">
#             </span>
#             <svg class="revo icon icon--svg icon-- icon--xs icon--currentColor">
#              <use xlink:href="https://exclusive.vwgroupretail.es/wp-content/mu-plugins/webspark-revolution/dist/svg/volkswagen.defs.svg#filter">
#              </use>
#             </svg>
#            </div>
#           </button>
#          </div>
#         </div>
#         <section class="sort-by__modal-section wsk-is-hidden" x-ref="mobileSortBy">
#          <div class="sort-by__main">
#           <div class="sort-by__content">
#            <p class="text text__display-small text__color--on-surface text__font--primary sort-by__content-title">
#             Ordenar por
#            </p>
#            <div class="field-input field-radio field-input--name-sort_by">
#             <label class="field-radio-main_label">
#             </label>
#             <div class="field-radio-container">
#              <input class="field-input__native" id="sort-by__radio-input_enteredInStockDate|desc" name="sort_by" required="required" type="radio" value="enteredInStockDate|desc" x-bind:checked="fields.sort_by === 'enteredInStockDate|desc'" x-model="fields.sort_by"/>
#              <label class="field-radio-label" for="sort-by__radio-input_enteredInStockDate|desc">
#               Añadido recientemente
#              </label>
#             </div>
#             <div class="field-radio-container">
#              <input class="field-input__native" id="sort-by__radio-input_price|asc" name="sort_by" required="required" type="radio" value="price|asc" x-bind:checked="fields.sort_by === 'price|asc'" x-model="fields.sort_by"/>
#              <label class="field-radio-label" for="sort-by__radio-input_price|asc">
#               Precio - Más bajo
#              </label>
#             </div>
#             <div class="field-radio-container">
#              <input class="field-input__native" id="sort-by__radio-input_price|desc" name="sort_by" required="required" type="radio" value="price|desc" x-bind:checked="fields.sort_by === 'price|desc'" x-model="fields.sort_by"/>
#              <label class="field-radio-label" for="sort-by__radio-input_price|desc">
#               Precio - Más alto
#              </label>
#             </div>
#             <div class="field-radio-container">
#              <input class="field-input__native" id="sort-by__radio-input_km|asc" name="sort_by" required="required" type="radio" value="km|asc" x-bind:checked="fields.sort_by === 'km|asc'" x-model="fields.sort_by"/>
#              <label class="field-radio-label" for="sort-by__radio-input_km|asc">
#               Kilometraje - Más bajo
#              </label>
#             </div>
#             <div class="field-radio-container">
#              <input class="field-input__native" id="sort-by__radio-input_km|desc" name="sort_by" required="required" type="radio" value="km|desc" x-bind:checked="fields.sort_by === 'km|desc'" x-model="fields.sort_by"/>
#              <label class="field-radio-label" for="sort-by__radio-input_km|desc">
#               Kilometraje - Más alto
#              </label>
#             </div>
#             <div class="field-radio-container">
#              <input class="field-input__native" id="sort-by__radio-input_year|asc" name="sort_by" required="required" type="radio" value="year|asc" x-bind:checked="fields.sort_by === 'year|asc'" x-model="fields.sort_by"/>
#              <label class="field-radio-label" for="sort-by__radio-input_year|asc">
#               Año de matriculación - Más bajo
#              </label>
#             </div>
#             <div class="field-radio-container">
#              <input class="field-input__native" id="sort-by__radio-input_year|desc" name="sort_by" required="required" type="radio" value="year|desc" x-bind:checked="fields.sort_by === 'year|desc'" x-model="fields.sort_by"/>
#              <label class="field-radio-label" for="sort-by__radio-input_year|desc">
#               Año de matriculación - Más alto
#              </label>
#             </div>
#             <div class="field__tooltip field__tooltip--error">
#             </div>
#            </div>
#           </div>
#           <div class="flex-layout flex-layout--row sort-by__actions">
#            <button @click="toggleMobileSortBy('cancel')" class="r-button button button--kind-secondary button--size-md button--theme-secondary button--radius-default">
#             <div class="button__content">
#              Cancelar
#             </div>
#            </button>
#            <button @click="handleApplySortBy" class="r-button button button--kind-primary button--size-md button--theme-primary button--radius-default">
#             <div class="button__content">
#              Aplicar
#             </div>
#            </button>
#           </div>
#          </div>
#         </section>
#         <section class="stock-listing__filters r-filters" x-ref="filtersWrapper">
#          <script id="sl-filters-data" type="application/json">
# ...
#   </script>
#   <script crossorigin="anonymous" defer="" id="ws-shared-vehiclelisting-vehicle-listing-js" integrity="sha256-ywMxeWnXPLCRPAyi5HSFqTsaUoLoAzZLqfqRpmveHtE=" src="https://webspark-assets.dealerk.com/webspark-revolution/2.0.9/dist/Shared/VehicleListing/vehicle-listing.js?ver=6.6.2">
#   </script>
#   <script id="dk-vendor-js" src="https://webspark-assets.dealerk.com/webspark/1.313.5/dist/static/vendor-libs.min.js?ver=1.313.5">
#   </script>
#   <script id="dk-app-script-js-extra">
#    var DK_Equipments = {"delete_icon":"https:\/\/exclusive.vwgroupretail.es\/wp-content\/plugins\/webspark\/img\/ico_elimina.gif","text_add_equipment":"A\u00f1ada","text_remove_equipment":"Eliminar"};
# var DK = {"isGoogleMapActive":"","ajaxurl":"https:\/\/exclusive.vwgroupretail.es\/wp-admin\/admin-ajax.php","restUrl":"https:\/\/exclusive.vwgroupretail.es\/wp-json","homeUrl":"https:\/\/exclusive.vwgroupretail.es","tyurl":"https:\/\/exclusive.vwgroupretail.es\/gracias","fonts":[{"family":"VWText","weight":400},{"family":"VWText","weight":700},{"family":"VWHead","weight":400},{"family":"VWHead","weight":700}],"htmlTemplates":{"arrow":"<svg xmlns=\"http:\/\/www.w3.org\/2000\/svg\" width=\"24\" height=\"24\" viewBox=\"0 0 24 24\">\n  <path fill-rule=\"evenodd\" d=\"M18.794 10.732H2v2h16.794A183.97 183.97 0 0114.318 17l1.362 1.464c5.012-4.666 6.32-5.972 6.32-6.732 0-.76-1.308-2.066-6.322-6.732L14.32 6.464a180.037 180.037 0 014.468 4.268h.006z\"\/>\n<\/svg>\n","arrowBase":"<svg xmlns=\"http:\/\/www.w3.org\/2000\/svg\" width=\"24\" height=\"24\" viewBox=\"0 0 24 24\">\n  <path fill-rule=\"evenodd\" d=\"M18.794 10.732H2v2h16.794A183.97 183.97 0 0114.318 17l1.362 1.464c5.012-4.666 6.32-5.972 6.32-6.732 0-.76-1.308-2.066-6.322-6.732L14.32 6.464a180.037 180.037 0 014.468 4.268h.006z\"\/>\n<\/svg>\n","checked":"<svg xmlns=\"http:\/\/www.w3.org\/2000\/svg\" width=\"24\" height=\"24\" viewBox=\"0 0 24 24\">\n  <polygon fill=\"#000000\" fill-rule=\"evenodd\" points=\"4.433 12 3 13.411 8.684 19.121 21.332 6.408 19.938 5 8.684 16.299\"\/>\n<\/svg>\n","circleCheck":"<svg xmlns=\"http:\/\/www.w3.org\/2000\/svg\" width=\"24\" height=\"24\" viewBox=\"0 0 24 24\">\n  <polygon fill=\"#000000\" fill-rule=\"evenodd\" points=\"4.433 12 3 13.411 8.684 19.121 21.332 6.408 19.938 5 8.684 16.299\"\/>\n<\/svg>\n","circleCheckFull":"<svg xmlns=\"http:\/\/www.w3.org\/2000\/svg\" width=\"24\" height=\"24\" viewBox=\"0 0 24 24\">\n  <polygon fill=\"#000000\" fill-rule=\"evenodd\" points=\"4.433 12 3 13.411 8.684 19.121 21.332 6.408 19.938 5 8.684 16.299\"\/>\n<\/svg>\n","warning":"<svg xmlns=\"http:\/\/www.w3.org\/2000\/svg\" width=\"24\" height=\"24\" viewBox=\"0 0 24 24\">\n  <path fill=\"#000000\" fill-rule=\"evenodd\" d=\"M10.3073622,4.34874105 C11.2394895,2.54891004 12.7534413,2.55192989 13.6855685,4.34874105 L20.6100862,16.761334 C21.54322,18.5621717 20.7439662,20.0207595 18.826361,20.0207595 L5.17462264,20.0207595 C3.25601083,20.0207595 2.45675702,18.5591518 3.38989088,16.761334 L10.3073622,4.34874105 Z M12.0125712,18.0991279 C12.2971841,18.1026362 12.5714447,17.9924972 12.7745802,17.7931164 C12.999496,17.5673367 13.1180358,17.2567184 13.1007241,16.9384986 C13.1070844,16.6331204 12.9906853,16.3379525 12.7776001,16.1191125 C12.5781834,15.9001787 12.2945941,15.7770702 11.9984786,15.7808892 C11.7042788,15.7764764 11.4226228,15.8998615 11.2264034,16.1191125 C11.0175915,16.3401037 10.9043748,16.6345395 10.9113323,16.9384986 C10.8924644,17.2589268 11.0128131,17.5719067 11.2415027,17.7971428 C11.4492152,17.9946546 11.7259704,18.1030443 12.0125712,18.0991279 Z M11.2072777,12.985514 L11.2082843,12.985514 C11.2277087,13.353097 11.3016644,13.7157511 11.4277268,14.0615875 C11.5113659,14.2863155 11.7319316,14.4300916 11.9712999,14.4159167 C12.2143969,14.4246159 12.4361135,14.2777489 12.522926,14.0505147 C12.6537296,13.715556 12.7272324,13.3609732 12.7403553,13.0016199 L13.0513999,9.170436 C13.0856248,8.81812008 13.1027373,8.47083725 13.1027373,8.12858751 C13.1242358,7.67463516 13.0526404,7.2210835 12.8923544,6.79582674 C12.741367,6.48034226 12.4075526,6.29466559 12.0598822,6.33278296 C11.7425844,6.32107156 11.4371177,6.45399585 11.2294233,6.69415843 C11.0041463,6.97951422 10.8919708,7.33790248 10.9143522,7.70077533 C10.9150233,8.01752411 10.9368333,8.53828059 10.9797823,9.26304475 L11.2072777,12.985514 Z\"\/>\n<\/svg>\n","phoneWave":"<svg xmlns=\"http:\/\/www.w3.org\/2000\/svg\" width=\"24\" height=\"24\" viewBox=\"0 0 24 24\">\n  <path fill-rule=\"evenodd\" d=\"M16.136 2H7.89c-.825 0-1.473.677-1.473 1.473v17.054c0 .825.677 1.473 1.473 1.473h8.247c.825 0 1.473-.677 1.473-1.473V3.473c0-.796-.648-1.473-1.473-1.473zm-8.247.884h8.247a.59.59 0 01.59.589v1.914H7.3V3.473a ...
# var dkL10n = {"validate_required":"campo obligatorio.","validate_remote":"Compruebe este campo.","validate_email":"Introduzca un email v\u00e1lido.","validate_url":"Introduzca una direcci\u00f3n web v\u00e1lida.","validate_date":"Introduzca una fecha v\u00e1lida.","validate_dateISO":"Introduzca una fecha v\u00e1lida (ISO).","validate_number":"Introduzca un n\u00famero v\u00e1lido.","validate_digits":"Introduzca s\u00f3lo n\u00fameros.","validate_creditcard":"Introduzca un n\u00famero de tarjeta de cr\u00e9dito v\u00e1lido.","validate_equalTo":"El valor no corresponde.","validate_accept":"Introduzca un valor con una extensi\u00f3n v\u00e1lida","validate_maxlength":"No introducir m\u00e1s de {0} car\u00e1cteres.","validate_minlength":"Introduzca al menos {0} car\u00e1cteres","validate_rangelength":"Introduzca un valor comprendido entre {0} y {1} caracteres","validate_range":"Introduzca un valor comprendido entre  {0} y  {1}.","validate_max":"Introduzca un valor menor o igual a   {0}.","validate_min":"Introduzca un valor mayor o igual a {0}","validate_phone":"N\u00famero de tel\u00e9fono no v\u00e1lido","new_estimate_dl":"Solicita informaci\u00f3n de la oferta","new_info_dl":"Solicite m\u00e1s informaci\u00f3n","new_promo_dl":"descubre las promociones actuales","new_testdrive_dl":"ven y pru\u00e9balo con nosotros","new_permuta_dl":"descubre el descuento entregando tu coche","used_estimate_dl":"Solicita informaci\u00f3n de la oferta","used_info_dl":"Solicite m\u00e1s informaci\u00f3n","used_promo_dl":"descubre las promociones actuales","used_testdrive_dl":"ven y pru\u00e9balo con nosotros","used_permuta_dl":"descubre el descuento entregando tu coche","new_estimate_cta":"Descubra la oferta","new_info_cta":"Solicite informaci\u00f3n","new_promo_cta":"Descubra las promociones","new_testdrive_cta":"Reserve un prueba de conducci\u00f3n","new_permuta_cta":"Reserve una permuta","used_estimate_cta":"Solicite Presupuesto","used_info_cta":"Solicite informaci\u00f3n","used_promo_cta":"Descubra las promociones","used_testdrive_cta":"Reserve un prueba de conducci\u00f3n","used_permuta_cta":"Reserve una permuta","validate_nonumber":"No se permiten los n\u00fameros","slider_fraction":"de","configurator_footer":"A partir de","product_range_footer":"Tuyo desde","loading_message":"cargando...","configurator_vehicle":"veh\u00edculos","configurator_cta":"descubre","bodytypesearch_more":"mostrar m\u00e1s bodytypes","bodytypesearch_less":"Mostrar menos bodytypes","bodytypesearch_select":"Selecciona una categor\u00eda","facet_show_more":"Leer m\u00e1s","facet_show_less":"Mostrar menos","ends_tomorrow":"Acaba ma\u00f1ana","hours":"Hora","days":"D\u00edas","remainHour":"restante","remainDay":"restantes","offer_pagination_prefix":"Oferta","show_more":"Leer m\u00e1s","show_less":"Mostrar menos","vat_disclaimer":"Los precios se entienden sin IVA","vat_disclaimer_included":"Los precios incluyen IVA","vat_excluded":"IVA no incluido","select_placeholder":"Escoger","select_class_code_label":"Tipo","select_brand_label":"Marca","select_type_label":"Carrocer\u00eda","select_monthly_fee_label":"Cuota mensual hasta","search_label":"Buscar","row_postcard_notify":"Seleccionar menos elementos para una mejor visualizaci\u00f3n","equipment_mounting":{"modal_title":"Para realizar esta acci\u00f3n","must_add_all":"Debes a\u00f1adir","must_add_all_and_add_one_of":"Debes a\u00f1adir todos y adem\u00e1s uno de","must_add_one_of":"Debes a\u00f1adir uno de","optionally_add_one_of":"Puedes a\u00f1adir uno de","optionally_remove_one_of":"Puedes quitar uno de","must_remove_all":"Debes eliminar","must_remove_one_of":"Debes eliminar uno de","btn_cancel":"Cancelar","btn_edit":"Editar","btn_apply":"Aplicar","btn_close":"Cerrar","your_configuration":"Tu configuraci\u00f3n","remove_all":"Eliminar todos","selected_optional":"Opcional seleccionado","included_optional":"Opcional incluido","included":"Incluido","worth":"Valor","total":"Total","not_compatible":"No compatible","used_estimate_c ...
# var DK_l10n_searchstock = {"vehicle_found":{"auto":{"singular":"veh\u00edculo","plural":"veh\u00edculos"},"moto":{"singular":"moto","plural":"motos"},"truck":{"singular":"cami\u00f3n","plural":"camiones"}},"select_default_all":{"type":"Seleccione el tipo","make":"Todas las marcas","bodyType":"Todos los tipos de carrocer\u00eda","price":"Todos los precios","model":"Todos los modelos","selected":"\u00a1{0} seleccionados!","minimumInstalmentAmount.min":"A partir de","minimumInstalmentAmount.max":"Hasta"},"generic_cta_multiselect":{"ok":"Ok","cancel":"Cancelar","select_all":"Seleccionar todo"}};
# var DK_l10n_productRange = {"productRange_footer":"Tuyo desde","productRange_vehicle":"Veh\u00edculos","productRange_cta":"Descubre"};
# var WEBSPARK_FBQ_PIXEL = {"pixel_ids":[245727915834796],"track_single":"1"};
# var dkProxyAPI = {"authURL":"https:\/\/exclusive.vwgroupretail.es\/wp-json\/webspark_app_auth\/v1\/get_authorization_token"};
# var WPl10n = {"numberDelimiter":".","currencySymbol":"\u20ac","currencyCode":"EUR","currencyLocalized":"0 \u20ac","country":"ES"};
# var DK_l10n_tradein = {"currency":"\u20ac","from":"Tuyo desde","to":"Hasta","ls":{"thank_you":"Gracias por elegir nuestro servicio","new_estimation":"Nueva estimaci\u00f3n","arrange_meetings":"\u00bfDesea concertar una cita con nosotros? Ll\u00e1menos de lunes a s\u00e1bado, de 9:00 a 19:00","call_us":"Llama al <a href=\"tel:690091743\">690 091 743<\/a> o <a href=\"tel:616049633\">616 049 633<\/a>","our_estimation":"Nuestra estimaci\u00f3n","max_value_of":"Sobre un valor estimado de","estimation_not_available":"Estimaci\u00f3n no definida","evaluation_disclaimer":{"avg":"Evaluaci\u00f3n indicativa","from_to":"El intervalo de evaluaci\u00f3n puede estar entre los valores anteriores"}},"registration_thank_you":{"it-IT":"grazie","es-ES":"gracias","de-DE":"\/danke\/","fr-FR":"\/merci\/","en-GB":"thank-you"}};
# var WEBSPARK_FBQ_EVENTS = [{"type":"PageView","value":null}];
# var OverlayTemplates = [];
#   </script>
#   <script defer="" id="dk-app-script-js" src="https://webspark-assets.dealerk.com/webspark/1.313.5/dist/app.min.js?ver=1.313.5">
#   </script>
#   <script defer="" id="dk-app-polyfill-js" src="https://webspark-assets.dealerk.com/webspark/1.313.5/dist/polyfill.min.js?ver=1.313.5">
#   </script>
#   <script defer="" id="dk-app-polyfill-ie-js" nomodule="" src="https://webspark-assets.dealerk.com/webspark/1.313.5/dist/polyfill-ie.min.js?ver=1.313.5">
#   </script>
#   <script id="dk-app-modules-js-extra">
#    var socialCredentials = {"facebook_app_id":"","google_app_id":"","google_app_secret":""};
#   </script>
#   <script defer="" id="dk-app-modules-js" src="https://webspark-assets.dealerk.com/webspark/1.313.5/dist/static/modules.min.js?ver=1.313.5">
#   </script>
#   <script defer="" id="dk-elektra-script-js" src="https://webspark-assets.dealerk.com/webspark/1.313.5/dist/elektra-lib.min.js?ver=1.313.5">
#   </script>
#   <script id="atomik-app-js-extra">
#    var atomikJs = {"loadingTxt":"cargando","maps":{"markers":[]}};
#   </script>
#   <script defer="" id="atomik-app-js" src="https://webspark-assets.dealerk.com/webspark-theme/1.313.5/dist/atomik-theme.min.js?ver=1.313.5">
#   </script>
#   <script id="webspark-boilerplate-theme-override-js-js" src="https://exclusive.vwgroupretail.es/wp-content/themes/websparksites-es-theme/volkswagen-retail/js/override.min.js?ver=1728930326">
#   </script>
#   <script id="webspark-css-custom-var-js-extra">
#    var WS_palette_config = {"--color__primary-light":"15,165,233","--color__primary":"0,152,221","--color__primary-dark":"10,129,183","--color__secondary-light":"81,91,99","--color__secondary":"55,63,69","--color__secondary-dark":"32,38,41","--color__tertiary-light":"153,153,153","--color__tertiary":"102,102,102","--color__tertiary-dark":"51,51,51","--color__white":"255,255,255","--color__gray-lighter":"242,242,242","--color__gray-light":"199,199,199","--color__gray":"148,148,148","--color__gray-dark":"97,97,97","--color__gray-darker":"46,46,46","--color__black":"0,0,0","--color__body-bg":"253,253,254","--color__wishlist":"217,30,24","--color__error":"194,42,27","--color__error-dark":"170,0,40","--color__error-light":"245,225,228","--color__warning":"236,182,12","--color__warning-dark":"199,153,10","--color__warning-light":"255,204,45","--color__error-light-new":"205,80,68","--color__yellow-paypal":"255,196,57","--color__yellow-paypal-light":"255,192,44","--color__reserved":"184,22,42","--color__reserved-dark":"165,19,37","--color__gold":"247,181,24","--color__offer":"238,51,51","--color__online":"47,93,152","--color__success":"58,186,121","--color__success-light":"81,200,139","--color__success-dark":"36,154,94","--color__info":"92,180,228","--color__category-demo":"51,124,151","--color__labela":"92,180,228","--color__labelb":"12,94,149","--color__labelc":"59,182,119","--color__labeld":"234,38,98","--color__labele":"45,220,108","--color__labelf":"83,127,160","--color__labelg":"238,51,51","--color__labelh":"123,119,201","--color__labeli":"186,129,0","--color__labell":"45,75,220","--color__labelm":"237,198,90","--color__twitter":"0,172,237","--color__twitter-hover":"0,132,180","--color__facebook":"59,89,151","--color__facebook-hover":"45,67,114","--color__google":"62,130,247","--color__google-hover":"49,104,197","--color__googleplus":"214,73,55","--color__googleplus-hover":"181,53,37","--color__pinterest":"189,8,28","--color__pinterest-hover":"189,8,28","--color__linkedin":"0,116,161","--color__linkedin-hover":"0,98,136","--color__whatsapp":"67,216,84","--color__whatsapp-hover":"0,150,136","--font__primary":"'Source Sans Pro'","--font__secondary":"'Source Sans Pro'","--color__grey-lighter":"243,245,246"};
#   </script>
#   <script defer="" id="webspark-css-custom-var-js" nomodule="" src="https://webspark-assets.dealerk.com/webspark/1.313.5/dist/css-custom-var.min.js?ver=1.313.5">
#   </script>
#   <script crossorigin="anonymous" defer="" id="ws-rentingoffers-purchase-method-listing-js" integrity="sha256-8TZvVmmSprrzRKulQ2RMYm+ql7KK7R6hXkOBDkCBtf4=" src="https://webspark-assets.dealerk.com/webspark-revolution/2.0.9/dist/RentingOffers/purchase-method-listing.js?ver=6.6.2">
#   </script>
#  </body>
# </html>
# <!-- Performance optimized by Redis Object Cache. Learn more: https://wprediscache.com -->
# <!--
# 	generated 7 seconds ago
# 	generated in 1.897 seconds
# 	served from batcache in 0.005 seconds
# 	expires in 293 seconds
# -->
